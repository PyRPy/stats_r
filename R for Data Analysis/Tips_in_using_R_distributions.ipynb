# %%
# you don't have to memorize distributions

# %%
# r - stands for 'random', d for density
# p for cumulative, q for quantile

# %%
myNumbers = rnorm(1000)

# %%
hist(myNumbers)
# Out:
# Plot with title “Histogram of myNumbers”

# %%
# are they equal? two-side or two tails
dnorm(-2, 0 , 1) == dnorm(2, 0 , 1)
# Out:
# [1] TRUE

# %%
pnorm(2, 0, 1) == 1 - pnorm(-2, 0, 1)
# Out:
# [1] TRUE

# %%
qnorm(0.95, 0, 1)
# Out:
# [1] 1.644854

# %%
qnorm(0.05, 0, 1)
# Out:
# [1] -1.644854

# %%
round(qnorm(0.95, 0, 1) + qnorm(0.05, 0, 1), 6)
# Out:
# [1] 0

# %%
# it's symmetric, like a 'bell'
