# %%
# quick plot using ggplot2 package

# %%
library(ggplot2)

# %%
data(mtcars)

# %%
head(mtcars[, 1:4])
# Out:
#                   mpg  cyl disp hp
# Mazda RX4         21.0 6   160  110
# Mazda RX4 Wag     21.0 6   160  110
# Datsun 710        22.8 4   108   93
# Hornet 4 Drive    21.4 6   258  110
# Hornet Sportabout 18.7 8   360  175
# Valiant           18.1 6   225  105

# %%
qplot(hp, mpg, geom = "point", 
  data = mtcars)
# Out:
# plot without title

# %%
qplot(hp, mpg, 
  geom = c("point", "smooth"),
  data = mtcars)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title
