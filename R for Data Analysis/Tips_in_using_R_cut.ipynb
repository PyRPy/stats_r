# %%
# cut numbers into groups

# %%
myNumbers = rnorm(100)

# %%
hist(myNumbers)
# Out:
# Plot with title “Histogram of myNumbers”

# %%
groups_std = cut(myNumbers, breaks = -3:3)

# %%
table(groups_std)
# Out:
# groups_std
# (-3,-2] (-2,-1]  (-1,0]   (0,1]   (1,2]   (2,3]
#       0      14      34      34      15       3

# %%
levels(groups_std)
# Out:
# [1] "(-3,-2]" "(-2,-1]" "(-1,0]"  "(0,1]"   "(1,2]"   "(2,3]"

# %%
# most of the numbers are between -2 and 2
# within -/+ two standard deviation
